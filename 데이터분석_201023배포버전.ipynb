# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
df1=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_강원.csv",encoding="cp949")
df2=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_경기.csv",encoding="cp949")
df3=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_경남.csv",encoding="cp949")
df4=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_경북.csv",encoding="cp949")
df5=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_광주.csv",encoding="cp949")
df6=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_대구.csv",encoding="cp949")
df7=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_대전.csv",encoding="cp949")
df8=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_부산.csv",encoding="cp949")
df9=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_서울.csv",encoding="cp949")
df10=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_세종.csv",encoding="cp949")
df11=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_울산.csv",encoding="cp949")
df12=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_인천.csv",encoding="cp949")
df13=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_전남.csv",encoding="cp949")
df14=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_전북.csv",encoding="cp949")
df15=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_제주.csv",encoding="cp949")
df16=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_충남.csv",encoding="cp949")
df17=pd.read_csv("C:/Users/user/Desktop/TAAS_데이터/201023_배포버전/빅데이터인턴분석자료통합버전_충북.csv",encoding="cp949")

# %%
data=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17])

# %%
data.columns
# Out:
# Index(['사고번호', '발생일시', '발생지_시도', '발생지_시군구', '법정동코드', '요일', '주야', '사고내용',
#        '사고유형_대분류', '사고유형_중분류', '사고유형', '가해자성별', '피해자성별', '연령가해자', '연령피해자',
#        '가해자음주_대분류', '가해자음주', '보호장구가해자_대분류', '보호장구가해자', '보호장구피해자_대분류',
#        '보호장구피해자', '법규위반가해자', '행동유형가해자_대분류', '행동유형가해자_중분류', '행동유형가해자',
#        '신체상해정도가해자', '신체상해정도피해자', '가해자신체상해주부위', '피해자신체상해주부위', '당사자종별가해자_대분류',
#        '당사자종별가해자', '당사자종별피해자_대분류', '당사자종별피해자', '차량용도가해자_대분류', '차량용도가해자_중분류',
#        '차량용도가해자', '차량용도피해자_대분류', '차량용도피해자_중분류', '차량용도피해자', '도로종류', '도로형태_대분류',
#        '도로형태', '노인보호구역_여부', '어린이보호구역_여부', '자전거도로_여부', '도로선형_대분류', '도로선형_중분류',
#        '도로선형', '기상상태', '노면상태_대분류', '노면상태', '교차로형태_대분류', '교차로형태', '사망자수',
#        '중상자수', '경상자수', '부상신고자수', '사고위치폴리곤'],
#       dtype='object')

# %%
data["교차로형태"].unique()
# Out:
# array(['교차로 - 사지', '교차로아님', '교차로 - 삼지', '교차로 - 오지이상', '교차로 - 회전', '기타불명'],
#       dtype=object)

# %%
data_삼지=data[data["교차로형태"]=='교차로 - 삼지']

# %%
data_삼지=data_삼지.sort_values(by=['당사자종별가해자'])

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('당사자종별가해자',data=data_삼지, ax=ax1)
plt.tight_layout()

# %%
len(data_삼지[data_삼지["당사자종별가해자"]=="승용차"])
# Out:
# 73858

# %%
len(data_사지[data_사지["당사자종별가해자"]=="승용차"])
# Out:
# 138847

# %%
data_사지=data[data["교차로형태"]=='교차로 - 사지']

# %%
data_사지=data_사지.sort_values(by=['당사자종별가해자'])

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('당사자종별가해자',data=data_사지, ax=ax1)
plt.tight_layout()

# %%
data_오지=data[data["교차로형태"]=='교차로 - 오지이상']

# %%
data_오지=data_오지.sort_values(by=['당사자종별가해자'])

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('당사자종별가해자',data=data_오지, ax=ax1)
plt.tight_layout()

# %%
len(data)
# Out:
# 1116035

# %%
data["당사자종별피해자_대분류"].unique()
# Out:
# array(['승용차', '없음', '원동기장치자전거', '이륜차', '보행자', '자전거', '승합차', '화물차', '농기계',
#        '특수차', '건설기계', '불명', '사륜오토바이(ATV)', '개인형이동수단(PM)', '기타', '열차'],
#       dtype=object)

# %%
data["발생일시"].unique()
# Out:
# array([2015010100, 2015010105, 2015010208, ..., 2016091506, 2018060104,
#        2018121003], dtype=int64)

# %%
pick_float=[]
pick_float2=[]

for i in data["연령피해자"]:
    pick_float=re.findall("[0-9.]+",i)
    pick_float2+=pick_float
    
pick_float3=pd.Series(pick_float2)

pick_float3=pd.Series(pick_float2)
data["연령피해자"]=pick_float3
data["연령피해자"]=pd.to_numeric(data["연령피해자"])

# %%
old=data[data["연령피해자"]>=65]

# %%
old_pedestrian=old[old["당사자종별피해자_대분류"]=="보행자"]

# %%
old_pedestrian=old_pedestrian.reset_index()

# %%
print(len(old_pedestrian[old_pedestrian["노인보호구역_여부"]=="예"]))
print(len(old_pedestrian[old_pedestrian["노인보호구역_여부"]=="아니오"]))
# Out:
# 12
# 29209

# %%
print(len(old_pedestrian[old_pedestrian["어린이보호구역_여부"]=="예"]))
print(len(old_pedestrian[old_pedestrian["어린이보호구역_여부"]=="아니오"]))
# Out:
# 377
# 28844

# %%
old_pedestrian["발생년"]=0
old_pedestrian["발생월"]=0
old_pedestrian["발생시간"]=0

# %%
for i in range(len(old_pedestrian)):
    old_pedestrian["발생년"][i]=str(old_pedestrian["발생일시"][i])[:4

# %%
for i in range(len(old_pedestrian)):
    old_pedestrian["발생월"][i]=str(old_pedestrian["발생일시"][i])[4:6]+"월"

# %%
for i in range(len(old_pedestrian)):
    old_pedestrian["발생시간"][i]=str(old_pedestrian["발생일시"][i])[8:]+"시"

# %%
old_pedestrian["발생년"].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
old_pedestrian["발생월"].unique()
# Out:
# array(['01월', '02월', '03월', '04월', '05월', '06월', '07월', '08월', '09월',
#        '10월', '11월', '12월'], dtype=object)

# %%
old_pedestrian["발생시간"].unique()
# Out:
# array(['20시', '18시', '11시', '12시', '13시', '10시', '21시', '19시', '08시',
#        '15시', '17시', '01시', '14시', '06시', '23시', '22시', '09시', '00시',
#        '16시', '07시', '03시', '02시', '05시', '04시'], dtype=object)

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('주야',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('발생월',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('요일',data=old_pedestrian, ax=ax1,order = ['월','화','수','목','금','토','일'])
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('발생시간',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('행동유형가해자',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('법규위반가해자',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('신체상해정도가해자',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('신체상해정도피해자',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('가해자신체상해주부위',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('피해자신체상해주부위',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('기상상태',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('노면상태',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('도로형태_대분류',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('교차로형태',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('도로형태',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('도로종류',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('도로선형',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('교차로형태',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('가해자음주_대분류',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
fig, (ax1) = plt.subplots(1,1, figsize=(16,4))
sns.countplot('가해자음주',data=old_pedestrian, ax=ax1)
plt.tight_layout()

# %%
맑음=old_pedestrian[old_pedestrian["기상상태"]=="맑음"]
그외=old_pedestrian[old_pedestrian["기상상태"]!="맑음"]

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(12,4))
sns.countplot('신체상해정도피해자',data=맑음, ax=ax1)
sns.countplot('신체상해정도피해자',data=그외, ax=ax2)
plt.tight_layout()

# %%
old_pedestrian["연령피해자"].unique()
# Out:
# array([ 75,  89,  70,  71,  67,  88,  79,  72,  66,  74,  69,  85,  92,
#         76,  86,  82,  73,  78,  68,  80,  65,  77,  84,  87,  81,  83,
#         98,  91,  90, 100,  93,  94,  95,  99, 117,  97,  96, 106, 109],
#       dtype=int64)

# %%
old_pedestrian[['연령피해자','사망자수']].groupby("연령피해자").sum().plot.bar(color='plum',figsize=(15,5))

# %%
old_pedestrian["사망자수"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
old_pedestrian["사고심각도"]=0

# %%
for i in range(len(old_pedestrian)):
    old_pedestrian["사고심각도"][i]=((old_pedestrian["사망자수"][i])*12)+((old_pedestrian["중상자수"][i])*3)+((old_pedestrian["경상자수"][i])*1)

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='발생년',y='사고심각도', data=old_pedestrian,hue="주야", ax=axes[0][0])
sns.pointplot(x='발생월',y='사고심각도', data=old_pedestrian, ax=axes[0][1])
sns.pointplot(x='요일',y='사고심각도', data=old_pedestrian, ax=axes[1][0])
sns.pointplot(x='발생시간',y='사고심각도', data=old_pedestrian, ax=axes[1][1])

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='사고내용',y='사고심각도', data=old_pedestrian, ax=axes[0][0])
sns.pointplot(x='사고유형',y='사고심각도', data=old_pedestrian, ax=axes[0][1])
sns.pointplot(x='법규위반가해자',y='사고심각도', data=old_pedestrian, ax=axes[1][0])
sns.pointplot(x='행동유형가해자',y='사고심각도', data=old_pedestrian, ax=axes[1][1])

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='보호장구가해자',y='사고심각도', data=old_pedestrian, ax=axes[0][0])
sns.pointplot(x='보호장구피해자',y='사고심각도', data=old_pedestrian, ax=axes[0][1])
sns.pointplot(x='신체상해정도가해자',y='사고심각도', data=old_pedestrian, ax=axes[1][0])
sns.pointplot(x='신체상해정도피해자',y='사고심각도', data=old_pedestrian, ax=axes[1][1])

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='가해자신체상해주부위',y='사고심각도', data=old_pedestrian, ax=axes[0][0])
sns.pointplot(x='피해자신체상해주부위',y='사고심각도', data=old_pedestrian, ax=axes[0][1])
sns.pointplot(x='당사자종별가해자',y='사고심각도', data=old_pedestrian, ax=axes[1][0])
sns.pointplot(x='당사자종별피해자',y='사고심각도', data=old_pedestrian, ax=axes[1][1])

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='차량용도가해자',y='사고심각도', data=old_pedestrian, ax=axes[0][0])
sns.pointplot(x='도로선형',y='사고심각도', data=old_pedestrian, ax=axes[0][1])
sns.pointplot(x='도로종류',y='사고심각도', data=old_pedestrian, ax=axes[1][0])
sns.pointplot(x='도로형태',y='사고심각도', data=old_pedestrian, ax=axes[1][1])

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='기상상태',y='사고심각도', data=old_pedestrian, ax=axes[0][0])
sns.pointplot(x='노면상태',y='사고심각도', data=old_pedestrian, ax=axes[0][1])
sns.pointplot(x='교차로형태',y='사고심각도', data=old_pedestrian, ax=axes[1][0])
sns.pointplot(x='발생지_시도',y='사고심각도', data=old_pedestrian, ax=axes[1][1])

fig.set_size_inches(15,10)
plt.show()

# %%
fig, (ax1,ax2,ax3,ax4,ax5) = plt.subplots(5,1,figsize=(15,10))

sns.pointplot(x='법규위반가해자',y='사고심각도', data=old_pedestrian, ax=ax1)
sns.pointplot(x='행동유형가해자',y='사고심각도', data=old_pedestrian, ax=ax2)
sns.pointplot(x='당사자종별가해자',y='사고심각도', data=old_pedestrian, ax=ax3)
sns.pointplot(x='차량용도가해자',y='사고심각도', data=old_pedestrian, ax=ax4)
sns.pointplot(x='도로형태',y='사고심각도', data=old_pedestrian, ax=ax5)

plt.tight_layout()
# fig.set_size_inches(15,15)
plt.show()

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %%
old_pedestrian["사고내용"].unique()
# Out:
# array(['중상', '경상', '사망', '부상신고'], dtype=object)

# %%
old_pedestrian["사고유형"].unique()
# Out:
# array(['횡단중', '길가장자리구역통행중', '기타', '보도통행중', '차도통행중', '도로이탈 추락'],
#       dtype=object)

# %%
old_pedestrian["가해자성별"].unique()
# Out:
# array(['남', '여', '기타불명'], dtype=object)

# %%
old_pedestrian["연령가해자"].unique()
# Out:
# array(['33세', '34세', '22세', '18세', '42세', '26세', '55세', '44세', '17세',
#        '57세', '60세', '49세', '23세', '43세', '66세', '불명', '50세', '64세',
#        '62세', '28세', '25세', '39세', '80세', '51세', '47세', '31세', '21세',
#        '53세', '40세', '45세', '46세', '27세', '19세', '29세', '71세', '35세',
#        '69세', '67세', '56세', '72세', '30세', '24세', '58세', '32세', '73세',
#        '63세', '54세', '16세', '68세', '61세', '48세', '36세', '59세', '37세',
#        '65세', '77세', '52세', '38세', '41세', '20세', '79세', '87세', '70세',
#        '13세', '78세', '84세', '74세', '11세', '75세', '12세', '89세', '10세',
#        '81세', '76세', '15세', '83세', '86세', '14세', '5세', '6세', '82세', '94세',
#        '85세', '88세', '9세', '8세', '98세', '7세', '92세', '99세'], dtype=object)

# %%
old_pedestrian["가해자음주"].unique()
# Out:
# array(['기타불명', '0.10%~0.14%', '0.05%~0.09%', '0.15%~0.19%', '0.20%~0.24%',
#        '0.25%~0.29%', '해당 없음', '0.30%~0.34%', '0.030~0.049%', '측정불능',
#        '측정불응', '0.03%미만'], dtype=object)

# %%
old_pedestrian["보호장구가해자"].unique()
# Out:
# array(['착용불명', '미착용', '착용', '기타불명'], dtype=object)

# %%
old_pedestrian["보호장구피해자"].unique()
# Out:
# array(['보행자'], dtype=object)

# %%
old_pedestrian["법규위반가해자"].unique()
# Out:
# array(['신호위반', '보행자 보호의무 위반', '안전운전 의무 불이행', '기타', '교차로 통행방법 위반',
#        '중앙선 침범', '과속', '안전거리 미확보'], dtype=object)

# %%
old_pedestrian["행동유형가해자"].unique()
# Out:
# array(['직진중', '우회전중', '좌회전중', '좌우회전중', '후진중', '기타', 'U턴중', '주정차중',
#        '진로변경중', '앞지르기중', '주행중대기', '주ㆍ정차중'], dtype=object)

# %%
for i in range(len(old_pedestrian)):
    old_pedestrian["행동유형가해자"][i]=old_pedestrian["행동유형가해자"][i].replace(" ","")

# %%
old_pedestrian["신체상해정도가해자"].unique()
# Out:
# array(['상해없음', '경상', '기타불명', '사망', '중상', '부상신고'], dtype=object)

# %%
old_pedestrian["신체상해정도피해자"].unique()
# Out:
# array(['경상', '사망', '부상신고', '중상', '상해없음'], dtype=object)

# %%
old_pedestrian["가해자신체상해주부위"].unique()
# Out:
# array(['상해없음', '허리', '얼굴', '기타', '앞목', '하퇴부', '발', '대퇴부', '팔', '가슴', '머리',
#        '뒷목', '불명', '목', '손', '배'], dtype=object)

# %%
old_pedestrian["법규위반가해자"].unique()
# Out:
# array(['안전운전 의무 불이행', '중앙선 침범', '보행자 보호의무 위반', '신호위반', '교차로 통행방법 위반',
#        '안전거리 미확보', '과속'], dtype=object)

# %%
old_pedestrian["당사자종별가해자"].unique()
# Out:
# array(['중형', '소형', '대형', '경형', '원동기장치자전거', '승용차', '화물차', '승합차', '이륜차',
#        '자전거', '건설기계', '특수차', '개인형이동수단(PM)', '사륜오토바이(ATV)', '농기계'],
#       dtype=object)

# %%
old_pedestrian["차량용도가해자"].unique()
# Out:
# array(['승용차', '화물차', '원동기장치자전거', '법인택시', '버스', '개인택시', '이륜차', '렌터카',
#        '시내버스', '기타/건설기계', '자전거', '어린이통학버스', '전세버스', '시외버스', '비사업용기타',
#        '일반화물', '마을버스', '기타', '고속버스', '위험물운송', '개인형이동수단(PM)',
#        '사륜오토바이(ATV)', '개별화물', '농기계'], dtype=object)

# %%
old_pedestrian["도로종류"].unique()
# Out:
# array(['시도', '기타', '지방도', '일반국도', '군도', '고속국도', '특별광역시도'], dtype=object)

# %%
old_pedestrian["노인보호구역_여부"].unique()
# Out:
# array(['아니오', '예'], dtype=object)

# %%
old_pedestrian["도로선형"].unique()
# Out:
# array(['평지', '내리막', '오르막', '평지  ', '기타/서비스구역'], dtype=object)

# %%
old_pedestrian["기상상태"].unique()
# Out:
# array(['맑음', '비', '흐림', '눈', '기타/불명', '안개'], dtype=object)

# %%
old_pedestrian["노면상태"].unique()
# Out:
# array(['건조', '젖음/습기', '기타', '서리/결빙', '적설', '침수', '해빙'], dtype=object)

# %%
old_pedestrian["교차로형태"].unique()
# Out:
# array(['교차로아님', '교차로 - 사지', '교차로 - 삼지', '교차로 - 오지이상', '교차로 - 회전'],
#       dtype=object)

# %%
old_pedestrian.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29221 entries, 0 to 29220
# Data columns (total 59 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         29221 non-null  int64
#  1   사고번호          29221 non-null  int64
#  2   발생일시          29221 non-null  int64
#  3   발생지_시도        29221 non-null  object
#  4   발생지_시군구       29221 non-null  object
#  5   법정동코드         29221 non-null  int64
#  6   요일            29221 non-null  object
#  7   주야            29221 non-null  object
#  8   사고내용          29221 non-null  object
#  9   사고유형_대분류      29221 non-null  object
#  10  사고유형_중분류      29221 non-null  object
#  11  사고유형          29221 non-null  object
#  12  가해자성별         29221 non-null  object
#  13  피해자성별         29221 non-null  object
#  14  연령가해자         29221 non-null  object
#  15  연령피해자         29221 non-null  int64
#  16  가해자음주_대분류     29221 non-null  object
#  17  가해자음주         29221 non-null  object
# ...

# %%
apriori_dataset.drop(['열이름','열이름'],axis=1,inplace=True)

# %%
df_original=old_pedestrian.drop(['사고번호','발생일시','발생지_시도','발생지_시군구','법정동코드','사고위치폴리곤','사고유형_대분류','사고유형_중분류','가해자음주_대분류','보호장구가해자_대분류','보호장구피해자_대분류','행동유형가해자_대분류','행동유형가해자_중분류','당사자종별가해자_대분류','당사자종별피해자_대분류','차량용도가해자_대분류','차량용도가해자_중분류','차량용도피해자_대분류','차량용도피해자_중분류','도로형태_대분류','도로선형_중분류','노면상태_대분류','교차로형태_대분류'],axis=1)

# %%
df_original["사고심각도"]=0

# %%
for i in range(len(old_pedestrian)):
    df_original["사고심각도"][i]=((df_original["사망자수"][i])*273)+((df_original["중상자수"][i])*32)+((df_original["경상자수"][i])*2)+((df_original["부상신고자수"][i])*1)

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29221 entries, 0 to 29220
# Data columns (total 35 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       29221 non-null  int64
#  1   요일          29221 non-null  object
#  2   주야          29221 non-null  object
#  3   사고내용        29221 non-null  object
#  4   사고유형        29221 non-null  object
#  5   가해자성별       29221 non-null  object
#  6   피해자성별       29221 non-null  object
#  7   가해자음주       29221 non-null  object
#  8   보호장구가해자     29221 non-null  object
#  9   보호장구피해자     29221 non-null  object
#  10  법규위반가해자     29221 non-null  object
#  11  행동유형가해자     29221 non-null  object
#  12  신체상해정도가해자   29221 non-null  object
#  13  신체상해정도피해자   29221 non-null  object
#  14  가해자신체상해주부위  29221 non-null  object
#  15  피해자신체상해주부위  29221 non-null  object
#  16  당사자종별가해자    29221 non-null  object
#  17  당사자종별피해자    29221 non-null  object
#  18  차량용도가해자     29221 non-null  object
# ...

# %%
df_original.drop(['연령가해자','연령피해자'],axis=1,inplace=True)

# %%
df=pd.get_dummies(df_original)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29221 entries, 0 to 29220
# Columns: 228 entries, index to 교차로형태_기타불명
# dtypes: int64(6), uint8(222)
# memory usage: 7.5 MB

# %%
corr_df=df.corr()
mask=np.array(corr_df)
mask[np.tril_indices_from(mask)]=False

plt.figure(figsize=(17, 14))
sns.heatmap(corr_df,mask=mask,square=True,cmap="Blues")

# %%
사고심각도_corr=corr_df["사고심각도"]

# %%
aa=corr_df["가해자성별_여"]
aa[aa>0.1]
# Out:
# 가해자성별_여         1.000000
# 당사자종별가해자_승용차    0.179131
# 차량용도가해자_승용차     0.371459
# Name: 가해자성별_여, dtype: float64

# %%
bb=corr_df["가해자성별_남"]
bb[bb>0.1]
# Out:
# 가해자성별_남           1.000000
# 신체상해정도가해자_상해없음    0.237552
# 당사자종별가해자_화물차      0.133691
# 차량용도가해자_개인택시      0.105520
# 차량용도가해자_법인택시      0.137835
# 차량용도가해자_이륜차       0.111459
# 차량용도가해자_화물차       0.169001
# Name: 가해자성별_남, dtype: float64

# %%
cc=corr_df["가해자성별_기타불명"]
cc[cc>0.1]
# Out:
# 부상신고자수            0.197783
# 사고내용_부상신고         0.221154
# 가해자성별_기타불명        1.000000
# 가해자음주_기타불명        0.167329
# 보호장구가해자_기타불명      0.493953
# 행동유형가해자_불명        0.894524
# 신체상해정도가해자_기타불명    0.762165
# 신체상해정도피해자_부상신고    0.221949
# 당사자종별가해자_불명       0.871940
# 차량용도가해자_기타/불명     0.534764
# 차량용도가해자_불명        0.679119
# Name: 가해자성별_기타불명, dtype: float64

# %%
사고심각도_corr[사고심각도_corr>0.1]
# Out:
# 사망자수             0.949408
# 중상자수             0.185400
# 사고심각도            1.000000
# 사고내용_사망          0.942408
# 사고내용_중상          0.149627
# 법규위반가해자_과속       0.203510
# 신체상해정도가해자_사망     0.145686
# 신체상해정도피해자_사망     0.939321
# 신체상해정도피해자_중상     0.148721
# 피해자신체상해주부위_머리    0.256205
# 도로종류_일반국도        0.106087
# Name: 사고심각도, dtype: float64

# %%
사고심각도_corr_sort=사고심각도_corr.sort_values(ascending = False)

# %%
사고심각도_corr_sort.head(20)
# Out:
# 사고심각도            1.000000
# 사망자수             0.949408
# 사고내용_사망          0.942408
# 신체상해정도피해자_사망     0.939321
# 피해자신체상해주부위_머리    0.256205
# 법규위반가해자_과속       0.203510
# 중상자수             0.185400
# 사고내용_중상          0.149627
# 신체상해정도피해자_중상     0.148721
# 신체상해정도가해자_사망     0.145686
# 도로종류_일반국도        0.106087
# 가해자성별_남          0.073312
# 사고유형_횡단중         0.072385
# 피해자신체상해주부위_가슴    0.070298
# 피해자신체상해주부위_얼굴    0.070201
# 피해자신체상해주부위_배     0.066739
# 차량용도가해자_화물차      0.066653
# 행동유형가해자_직진중      0.065657
# 신체상해정도가해자_중상     0.059811
# 주야_야             0.056637
# Name: 사고심각도, dtype: float64

# %%
사고심각도_corr_sort.tail(20)
# Out:
# 도로종류_기타           -0.054985
# 차량용도가해자_불명        -0.055945
# 주야_주              -0.056637
# 피해자신체상해주부위_허리     -0.056639
# 가해자신체상해주부위_상해없음   -0.056657
# 피해자신체상해주부위_발      -0.061341
# 당사자종별가해자_불명       -0.071255
# 행동유형가해자_불명        -0.072886
# 가해자성별_기타불명        -0.080138
# 신체상해정도가해자_기타불명    -0.085659
# 피해자신체상해주부위_팔      -0.093725
# 부상신고자수            -0.101971
# 신체상해정도피해자_부상신고    -0.110656
# 사고내용_부상신고         -0.112019
# 경상자수              -0.375856
# 신체상해정도피해자_경상      -0.428655
# 사고내용_경상           -0.433086
# 보호장구피해자_보행자             NaN
# 당사자종별피해자_보행자            NaN
# 차량용도피해자_보행자             NaN
# Name: 사고심각도, dtype: float64

# %%
apriori_df9=df9[["가해자성별","당사자종별가해자","차량용도가해자","행동유형가해자","법규위반가해자"]]

# %%
df9["가해자성별"].unique()
# Out:
# array(['남', '여', '기타불명'], dtype=object)

# %%
for i in range(len(old_pedestrian)):
    df9["행동유형가해자"][i]=df9["행동유형가해자"][i].replace(" ","")

# %%
apriori_df9["가해자성별"].unique()
# Out:
# array(['남', '여', '기타불명'], dtype=object)

# %%
apriori_df9["당사자종별가해자"].unique()
# Out:
# array(['중형', '소형', '원동기장치자전거', '경형', '대형', '자전거', '종별_기타', '건설기계', '농기계',
#        '사발이', '승용차', '화물차', '이륜차', '승합차', '특수차', '개인형이동수단(PM)',
#        '사륜오토바이(ATV)'], dtype=object)

# %%
apriori_df9["차량용도가해자"].unique()
# Out:
# array(['법인택시', '승용차', '원동기장치자전거', '화물차', '이륜차', '렌터카', '개인택시', '비사업용기타',
#        '시내버스', '전세버스', '자전거', '용도_기타', '개별화물', '버스', '일반화물', '기타/건설기계',
#        '시외버스', '고속버스', '콘크리트믹서', '덤프트럭', '용달화물', '어린이통학버스', '위험물운송',
#        '특수여객(장의)', '사륜오토바이(ATV)', '불명', '마을버스', '개인형이동수단(PM)', '농기계'],
#       dtype=object)

# %%
apriori_df9["행동유형가해자"].unique()
# Out:
# array(['진로변경중', '직진중', '좌우회전중', '행동_기타', '주ㆍ정차중', 'U턴중', '후진중', '출발중',
#        '앞지르기중', '좌회전중', '우회전중', '주정차중', '주행중대기'], dtype=object)

# %%
apriori_df9["법규위반가해자"].unique()
# Out:
# array(['안전거리미확보', '안전운전의무불이행', '신호위반', '위반_기타', '교차로통행방법위반', '보행자보호의무위반',
#        '중앙선침범', '과속'], dtype=object)

# %%
for i in range(len(apriori_df9)):
    if apriori_df9["당사자종별가해자"][i]=="기타" :
        apriori_df9["당사자종별가해자"][i]="종별_기타"

# %%
for i in range(len(apriori_df9)):
    if apriori_df9["당사자종별가해자"][i]=="불명" :
        apriori_df9["당사자종별가해자"][i]="종별_기타"

# %%
for i in range(len(apriori_df9)):
    if apriori_df9["차량용도가해자"][i]=="불명" :
        apriori_df9["차량용도가해자"][i]="용도_기타"

# %%
for i in range(len(apriori_df9)):
    if apriori_df9["차량용도가해자"][i]=="기타" :
        apriori_df9["차량용도가해자"][i]="용도_기타"

# %%
for i in range(len(apriori_df9)):
    apriori_df9["행동유형가해자"][i]=apriori_df9["행동유형가해자"][i].replace(" ","")

# %%
for i in range(len(apriori_df9)):
    if apriori_df9["행동유형가해자"][i]=="기타" :
        apriori_df9["행동유형가해자"][i]="행동_기타"

# %%
for i in range(len(apriori_df9)):
    if apriori_df9["행동유형가해자"][i]=="불명" :
        apriori_df9["행동유형가해자"][i]="행동_기타"

# %%
for i in range(len(apriori_df9)):
    if apriori_df9["법규위반가해자"][i]=="기타" :
        apriori_df9["법규위반가해자"][i]="위반_기타"

# %%
for i in range(len(apriori_df9)):
    apriori_df9["법규위반가해자"][i]=apriori_df9["법규위반가해자"][i].replace(" ","")

# %%
apriori_df9[apriori_df9["차량용도가해자"]=="승용차"]="확인필요"

# %%
apriori_df9["차량용도가해자"].unique()
# Out:
# array(['법인택시', '확인필요', '원동기장치자전거', '화물차', '이륜차', '렌터카', '개인택시', '비사업용기타',
#        '시내버스', '전세버스', '자전거', '용도_기타', '개별화물', '버스', '일반화물', '기타/건설기계',
#        '시외버스', '고속버스', '콘크리트믹서', '덤프트럭', '용달화물', '어린이통학버스', '위험물운송',
#        '특수여객(장의)', '사륜오토바이(ATV)', '마을버스', '개인형이동수단(PM)', '농기계'],
#       dtype=object)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
apriori_list=apriori_df9.values.tolist()

# %%
te = TransactionEncoder()
te_ary = te.fit(apriori_list).transform(apriori_list)

# %%
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
len(apriori_df9)
# Out:
# 198382

# %%
len(apriori_df9[ (apriori_df9["가해자성별"]=="여") & (apriori_df9["차량용도가해자"]=="승용차") ])
# Out:
# 25665

# %%
25665/198382
# Out:
# 0.12937161637648578

# %%
len(apriori_df9[ (apriori_df9["가해자성별"]=="남") & (apriori_df9["차량용도가해자"]=="법인택시") ])
# Out:
# 30080

# %%
30080/198382
# Out:
# 0.15162665967678518

# %%
frequent_itemsets = apriori(df, min_support=0.1, use_colnames=True)

# %%
df_000=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3)

# %%
df_000.sort_values(by=['lift'], axis=0, ascending=False)
# Out:
#               antecedents       consequents  antecedent support  \
# 12                    (여)             (승용차)            0.156975
# 48          (직진중, 승용차, 남)       (안전운전의무불이행)            0.206576
# 0                  (법인택시)               (남)            0.154308
# 41             (직진중, 승용차)       (안전운전의무불이행)            0.269228
# 42            (안전운전의무불이행)        (직진중, 승용차)            0.563272
# 34         (안전운전의무불이행, 남)             (직진중)            0.455092
# 37                  (직진중)    (안전운전의무불이행, 남)            0.493220
# 47    (안전운전의무불이행, 승용차, 남)             (직진중)            0.240869
# 40       (안전운전의무불이행, 승용차)             (직진중)            0.319444
# 43                  (직진중)  (안전운전의무불이행, 승용차)            0.493220
# 51         (안전운전의무불이행, 남)        (직진중, 승용차)            0.455092
# 52             (직진중, 승용차)    (안전운전의무불이행, 남)            0.269228
# 17            (안전운전의무불이행)             (직진중)            0.563272
# 18                  (직진중)       (안전운전의무불이행)            0.493220
# ...

# %%
data.columns
# Out:
# Index(['사고번호', '발생일시', '발생지_시도', '발생지_시군구', '법정동코드', '요일', '주야', '사고내용',
#        '사고유형_대분류', '사고유형_중분류', '사고유형', '가해자성별', '피해자성별', '연령가해자', '연령피해자',
#        '가해자음주_대분류', '가해자음주', '보호장구가해자_대분류', '보호장구가해자', '보호장구피해자_대분류',
#        '보호장구피해자', '법규위반가해자', '행동유형가해자_대분류', '행동유형가해자_중분류', '행동유형가해자',
#        '신체상해정도가해자', '신체상해정도피해자', '가해자신체상해주부위', '피해자신체상해주부위', '당사자종별가해자_대분류',
#        '당사자종별가해자', '당사자종별피해자_대분류', '당사자종별피해자', '차량용도가해자_대분류', '차량용도가해자_중분류',
#        '차량용도가해자', '차량용도피해자_대분류', '차량용도피해자_중분류', '차량용도피해자', '도로종류', '도로형태_대분류',
#        '도로형태', '노인보호구역_여부', '어린이보호구역_여부', '자전거도로_여부', '도로선형_대분류', '도로선형_중분류',
#        '도로선형', '기상상태', '노면상태_대분류', '노면상태', '교차로형태_대분류', '교차로형태', '사망자수',
#        '중상자수', '경상자수', '부상신고자수', '사고위치폴리곤'],
#       dtype='object')

# %%
data_apriori.columns
# Out:
# Index(['발생일시', '요일', '주야', '사고내용', '사고유형', '가해자성별', '피해자성별', '연령가해자', '연령피해자',
#        '가해자음주', '보호장구가해자', '법규위반가해자', '행동유형가해자', '신체상해정도가해자', '신체상해정도피해자',
#        '가해자신체상해주부위', '피해자신체상해주부위', '당사자종별가해자', '당사자종별피해자', '차량용도피해자', '도로종류',
#        '도로형태', '노인보호구역_여부', '어린이보호구역_여부', '자전거도로_여부', '도로선형_대분류', '도로선형',
#        '기상상태', '노면상태', '교차로형태', '사망자수', '중상자수', '경상자수', '부상신고자수'],
#       dtype='object')

# %%
data_apriori=df9.drop(['보호장구피해자','사고번호','발생지_시도','발생지_시군구','법정동코드','사고위치폴리곤','사고유형_대분류','사고유형_중분류','가해자음주_대분류','보호장구가해자_대분류','보호장구피해자_대분류','행동유형가해자_대분류','행동유형가해자_중분류','당사자종별가해자_대분류','당사자종별피해자_대분류','차량용도가해자_대분류','차량용도가해자_중분류','차량용도피해자_대분류','차량용도피해자_중분류','도로형태_대분류','도로선형_중분류','노면상태_대분류','교차로형태_대분류','차량용도가해자'],axis=1)

# %%
pick_float=[]
pick_float2=[]

for i in data_apriori["연령가해자"]:
    pick_float=re.findall("[0-9.]+",i)
    pick_float2+=pick_float
    
pick_float3=pd.Series(pick_float2)

pick_float3=pd.Series(pick_float2)
data_apriori["연령가해자"]=pick_float3
data_apriori["연령가해자"]=pd.to_numeric(data_apriori["연령가해자"])

# %%
data_apriori["발생월"]=0
data_apriori["발생시간"]=0

# %%
for i in range(len(old_pedestrian)):
    data_apriori["발생월"][i]=str(data_apriori["발생일시"][i])[4:6]+"월"

# %%
for i in range(len(old_pedestrian)):
    data_apriori["발생시간"][i]=str(data_apriori["발생일시"][i])[8:]+"시"

# %%
data_apriori=data_apriori.drop(['발생일시','연령피해자','피해자성별','노인보호구역_여부','어린이보호구역_여부','자전거도로_여부','도로선형_대분류','사망자수','중상자수','경상자수','부상신고자수'],axis=1)

# %%
data_apriori.columns
# Out:
# Index(['요일', '주야', '사고내용', '사고유형', '가해자성별', '연령가해자', '가해자음주', '보호장구가해자',
#        '법규위반가해자', '행동유형가해자', '신체상해정도가해자', '신체상해정도피해자', '가해자신체상해주부위',
#        '피해자신체상해주부위', '당사자종별가해자', '당사자종별피해자', '차량용도피해자', '도로종류', '도로형태', '도로선형',
#        '기상상태', '노면상태', '교차로형태', '발생월', '발생시간'],
#       dtype='object')

# %%
apriori=data_apriori

# %%
apriori["요일"].unique()
# Out:
# array(['목', '금', '토', '수', '월', '화', '일'], dtype=object)

# %%
apriori["주야"].unique()
# Out:
# array(['야', '주'], dtype=object)

# %%
apriori["사고내용"].unique()
# Out:
# array(['경상', '중상', '부상신고', '사망'], dtype=object)

# %%
apriori["사고유형"].unique()
# Out:
# array(['측면충돌', '차도통행중', '주정차중추돌', '횡단중', '진행중추돌', '사고유형_기타', '길가장자리구역통행중',
#        '공작물충돌', '보도통행중', '정면충돌', '전도전복', '주/정차차량충돌', '도로이탈기타', '도로이탈추락',
#        '추돌', '전도', '후진중충돌', '전복'], dtype=object)

# %%
for i in range(len(apriori)):
    apriori["사고유형"][i]=apriori["사고유형"][i].replace(" ","")

# %%
# apriori[apriori["사고유형"]=="기타"]["사고유형"]="사고유형_기타"

# %%
for i in range(len(apriori)):
    if apriori["사고유형"][i]=="기타" :
        apriori["사고유형"][i]="사고유형_기타"

# %%
apriori["가해자성별"].unique()
# Out:
# array(['남', '여', '기타불명'], dtype=object)

# %%
for i in range(len(apriori)):
    if apriori["가해자성별"][i]=="기타불명" :
        apriori["가해자성별"][i]="가해자성별_불명"

# %%
# apriori[apriori["가해자성별"]=="기타"]="사고유형_기타"

# %%
apriori["연령가해자"].unique()
# Out:
# array([ 62.,  27.,  29.,  39.,  54.,  66.,  57.,  56.,  59.,  55.,  53.,
#         31.,  46.,  26.,  72.,  69.,  25.,  61.,  71.,  52.,  41.,  38.,
#         58.,  42.,  45.,  28.,  60.,  49.,  32.,  51.,  64.,  74.,  65.,
#         50.,  37.,  67.,  40.,  68.,  47.,  75.,  43.,  18.,  33.,  22.,
#         63.,  35.,  24.,  34.,  44.,  70.,  23.,  77.,  21.,  78.,  48.,
#         30.,  36.,  17.,  76.,  19.,  10.,  73.,  20.,  83.,  80.,  16.,
#         88.,  14.,  13.,  79.,  12.,  82.,  15.,   7.,  93.,  85.,   4.,
#          8.,  11.,  81.,   9.,  86.,  89.,  84.,  91.,  87.,   6.,  90.,
#          5.,  98.,  95.,  99.,  94., 117., 113., 100., 106.,  92.,   1.,
#         nan])

# %%
apriori["가해자음주"].unique()
# Out:
# array(['기타불명', '0.15%~0.19%', '0.10%~0.14%', '0.05%~0.09%', '0.20%~0.24%',
#        '측정불응', '0.30%~0.34%', '0.25%~0.29%', '0.35%이상', '측정불능', '해당 없음',
#        '0.030~0.049%', '0.03%미만'], dtype=object)

# %%
apriori["보호장구가해자"].unique()
# Out:
# array(['착용', '기타불명', '착용불명', '미착용'], dtype=object)

# %%
apriori["법규위반가해자"].unique()
# Out:
# array(['안전거리 미확보', '안전운전 의무 불이행', '신호위반', '기타', '교차로 통행방법 위반',
#        '보행자 보호의무 위반', '중앙선 침범', '과속'], dtype=object)

# %%
for i in range(len(apriori)):
    apriori["법규위반가해자"][i]=apriori["법규위반가해자"][i].replace(" ","")

# %%
for i in range(len(apriori)):
    if apriori["법규위반가해자"][i]=="기타" :
        apriori["법규위반가해자"][i]="법규위반_기타"

# %%
apriori["행동유형가해자"].unique()
# Out:
# array(['진로변경중', '직진중', '좌우회전중', '기타', '주ㆍ정차중', 'U턴중', '불명', '후진중', '출발중',
#        '앞지르기중', '주ㆍ정차중 ', '직진 중', '진로변경 중', 'U턴 중', '좌회전 중', '우회전 중',
#        '주정차중', '주행 중 대기', '앞지르기 중', '후진 중'], dtype=object)

# %%
for i in range(len(apriori)):
    apriori["행동유형가해자"][i]=apriori["행동유형가해자"][i].replace(" ","")

# %%
for i in range(len(apriori)):
    if apriori["행동유형가해자"][i]=="기타" :
        apriori["행동유형가해자"][i]="행동유형_기타"

# %%
for i in range(len(apriori)):
    if apriori["행동유형가해자"][i]=="불명" :
        apriori["행동유형가해자"][i]="행동유형_기타"

# %%
apriori["신체상해정도가해자"].unique()
# Out:
# array(['상해없음', '부상신고', '경상', '중상', '기타불명', '사망'], dtype=object)

# %%
apriori["신체상해정도피해자"].unique()
# Out:
# array(['상해없음', '중상', '경상', '사망', '부상신고', '없음', '기타불명'], dtype=object)

# %%
for i in range(len(apriori)):
    if apriori["신체상해정도피해자"][i]=="없음" :
        apriori["신체상해정도피해자"][i]="상해없음"

# %%
for i in range(len(apriori)):
    if apriori["신체상해정도피해자"][i]=="기타불명" :
        apriori["신체상해정도피해자"][i]="상해불명"

# %%
apriori["가해자신체상해주부위"].unique()
# Out:
# array(['상해없음', '목', '기타', '얼굴', '팔', '허리', '하퇴부', '가슴', '어깨', '대퇴부', '발',
#        '손', '머리', '배', '등', '뒷목', '불명', '앞목', '없음'], dtype=object)

# %%
apriori["피해자신체상해주부위"].unique()
# Out:
# array(['상해없음', '기타', '목', '허리', '어깨', '머리', '하퇴부', '손', '발', '가슴', '팔',
#        '대퇴부', '없음', '얼굴', '배', '등', '뒷목', '앞목', '불명'], dtype=object)

# %%
apriori["당사자종별가해자"].unique()
# Out:
# array(['중형', '소형', '원동기장치자전거', '경형', '대형', '자전거', '불명', '건설기계', '농기계',
#        '사발이', '승용차', '화물차', '이륜차', '승합차', '특수차', '기타', '개인형이동수단(PM)',
#        '사륜오토바이(ATV)'], dtype=object)

# %%
for i in range(len(apriori)):
    if apriori["당사자종별가해자"][i]=="기타" :
        apriori["당사자종별가해자"][i]="당사자종별_기타"

# %%
apriori["당사자종별피해자"].unique()
# Out:
# array(['중형', '보행자', '대형', '소형', '자전거', '경형', '없음', '원동기장치자전거', '건설기계',
#        '불명', '농기계', '사발이', '승용차', '이륜차', '승합차', '화물차', '사륜오토바이(ATV)',
#        '기타', '개인형이동수단(PM)', '특수차'], dtype=object)

# %%
apri=apriori[apriori["당사자종별피해자"]=="보행자"]

# %%
apri["차량용도피해자"].unique()
# Out:
# array(['법인택시', '보행자', '개인택시', '승용차', '비사업용기타', '이륜차', '화물차', '자전거', '렌터카',
#        '없음', '원동기장치자전거', '시내버스', '버스', '개별화물', '일반화물', '전세버스', '시외버스',
#        '기타', '고속버스', '용달화물', '덤프트럭', '어린이통학버스', '기타/불명', '콘크리트믹서',
#        '기타/건설기계', '사륜오토바이(ATV)', '위험물운송', '특수여객(장의)', '마을버스', '불명',
#        '개인형이동수단(PM)', '농기계'], dtype=object)

# %%
apri=apri.reset_index()

# %%
for i in range(len(apri)):
    if apri["차량용도피해자"][i]=="없음" :
        apri["차량용도피해자"][i]="차량용도_기타"

# %%
for i in range(len(apri)):
    if apri["차량용도피해자"][i]=="기타" :
        apri["차량용도피해자"][i]="차량용도_기타"

# %%
for i in range(len(apri)):
    if apri["차량용도피해자"][i]=="기타/불명" :
        apri["차량용도피해자"][i]="차량용도_기타"

# %%
for i in range(len(apri)):
    if apri["차량용도피해자"][i]=="불명" :
        apri["차량용도피해자"][i]="차량용도_기타"

# %%
apri["도로종류"].unique()
# Out:
# array(['특별광역시도', '기타', '고속국도'], dtype=object)

# %%
for i in range(len(apri)):
    if apri["도로종류"][i]=="기타" :
        apri["도로종류"][i]="도로종류_기타"

# %%
apri["도로선형"].unique()
# Out:
# array(['평지', '오르막', '평지  ', '내리막', '기타/서비스구역'], dtype=object)

# %%
for i in range(len(apri)):
    apri["도로선형"][i]=apri["도로선형"][i].replace(" ","")

# %%
apri["도로형태"].unique()
# Out:
# array(['기타단일로', '교차로내', '횡단보도상', '교차로부근', '기타/불명', '횡단보도부근', '터널안',
#        '고가도로위', '교량위', '지하차도(도로)내', '기타', '교차로횡단보도내', '주차장', '불명'],
#       dtype=object)

# %%
for i in range(len(apri)):
    if apri["도로형태"][i]=="기타" :
        apri["도로형태"][i]="도로형태_기타"

# %%
for i in range(len(apri)):
    if apri["도로형태"][i]=="불명" :
        apri["도로형태"][i]="도로형태_기타"

# %%
for i in range(len(apri)):
    if apri["도로형태"][i]=="기타/불명" :
        apri["도로형태"][i]="도로형태_기타"

# %%
apri["기상상태"].unique()
# Out:
# array(['맑음', '비', '흐림', '기타/불명', '눈', '안개'], dtype=object)

# %%
for i in range(len(apri)):
    if apri["기상상태"][i]=="기타/불명" :
        apri["기상상태"][i]="기상_불명"

# %%
apri["노면상태"].unique()
# Out:
# array(['건조', '젖음/습기', '기타', '서리/결빙', '적설', '해빙', '침수'], dtype=object)

# %%
for i in range(len(apri)):
    if apri["노면상태"][i]=="기타" :
        apri["노면상태"][i]="노면_기타"

# %%
apri["교차로형태"].unique()
# Out:
# array(['교차로아님', '교차로 - 사지', '교차로 - 삼지', '교차로 - 오지이상', '교차로 - 회전', '기타불명'],
#       dtype=object)

# %%
for i in range(len(apri)):
    apri["교차로형태"][i]=apri["교차로형태"][i].replace(" ","")

# %%
for i in range(len(apri)):
    if apri["교차로형태"][i]=="기타불명" :
        apri["교차로형태"][i]="교차로_기타"

# %%
apri["발생월"].unique()
# Out:
# array(['01월', '02월', '03월', '04월', '05월', '06월', '07월', '08월', '09월',
#        '10월', '11월', '12월', 0], dtype=object)

# %%
apri["발생시간"].unique()
# Out:
# array(['01시', '00시', '07시', '17시', '22시', '09시', '21시', '20시', '18시',
#        '12시', '04시', '14시', '05시', '03시', '19시', '13시', '08시', '10시',
#        '15시', '06시', '23시', '11시', '16시', '02시', 0], dtype=object)

# %%
aprio=apri.drop(["가해자음주","보호장구가해자","신체상해정도가해자","가해자신체상해주부위","피해자신체상해주부위","차량용도피해자"],axis=1)

# %%
aprio.columns
# Out:
# Index(['요일', '주야', '사고내용', '사고유형', '가해자성별', '연령가해자', '법규위반가해자', '행동유형가해자',
#        '신체상해정도피해자', '당사자종별가해자', '당사자종별피해자', '도로종류', '도로형태', '도로선형', '기상상태',
#        '노면상태', '교차로형태', '발생월', '발생시간'],
#       dtype='object')

# %%
aprio.drop(["index"],axis=1,inplace=True)

# %%
aprio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52125 entries, 0 to 52124
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   요일         52125 non-null  object
#  1   주야         52125 non-null  object
#  2   사고내용       52125 non-null  object
#  3   사고유형       52125 non-null  object
#  4   가해자성별      52125 non-null  object
#  5   법규위반가해자    52125 non-null  object
#  6   행동유형가해자    52125 non-null  object
#  7   신체상해정도피해자  52125 non-null  object
#  8   당사자종별가해자   52125 non-null  object
#  9   당사자종별피해자   52125 non-null  object
#  10  도로종류       52125 non-null  object
#  11  도로형태       52125 non-null  object
#  12  도로선형       52125 non-null  object
#  13  기상상태       52125 non-null  object
#  14  노면상태       52125 non-null  object
#  15  교차로형태      52125 non-null  object
#  16  발생월        52125 non-null  object
#  17  발생시간       52125 non-null  object
# dtypes: object(18)
# memory usage: 7.2+ MB

# %%
aprio.drop(["연령가해자"],axis=1,inplace=True)

# %%
aaa=aprio[["요일","주야","사고내용","사고유형","가해자성별","법규위반가해자","행동유형가해자","신체상해정도피해자","당사자종별가해자","도로종류","도로형태","도로선형","기상상태","노면상태","교차로형태"]]

# %%
aaa.to_csv("apriori.csv",encoding="cp949")

# %%
aaa=apri[["요일","주야","사고내용","사고유형","가해자성별","법규위반가해자","행동유형가해자","신체상해정도피해자","당사자종별가해자","도로종류","도로형태","도로선형","기상상태","가해자신체상해주부위"]]

# %%
type(aaa)
# Out:
# pandas.core.frame.DataFrame

# %%
apriori_list=aaa.values.tolist()

# %%
te = TransactionEncoder()
te_ary = te.fit(apriori_list).transform(apriori_list)

# %%
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        가해자성별_불명  길가장자리구역통행중      남  보도통행중  사고유형_기타      여  차도통행중    횡단중  후진중충돌
# 0         False       False   True  False    False  False   True  False  False
# 1         False       False   True  False    False  False  False   True  False
# 2         False       False  False  False    False   True   True  False  False
# 3         False       False   True  False    False  False  False   True  False
# 4         False       False  False  False    False   True  False   True  False
# ...         ...         ...    ...    ...      ...    ...    ...    ...    ...
# 52120     False        True   True  False    False  False  False  False  False
# 52121     False       False  False  False     True   True  False  False  False
# 52122     False        True   True  False    False  False  False  False  False
# 52123     False       False  False  False    False   True   True  False  False
# 52124     False       False  False  False    False   True  False   True  False
#
# ...

# %%
frequent_itemsets = apriori(df, min_support=0.5, use_colnames=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-349-17d620acc6bf> in <module>
# ----> 1 frequent_itemsets = apriori(df, min_support=0.5, use_colnames=True)
#
# TypeError: 'DataFrame' object is not callable

# %%
df_000=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3)

# %%
df_000.sort_values(by=['lift'], axis=0, ascending=False)
